# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo-Bruges/ciencia-de-datos-unab/blob/notebooks/INTRODUCCI%C3%93N_AL_CURSO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # **CURSO ANÁLISIS EXPLORATORIO DE DATOS**

# %% [markdown]
# # **PRINCIPALES ESTRUCTURAS DE DATOS EN PYTHON**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aplicaciones Prácticas y Usos Comunes
# Listas: Muy útiles para coleccionar y ordenar elementos en aplicaciones que requieren mutabilidad, como listas de tareas, nombres de archivos, o colecciones de datos.
#
# Tuplas: Se usan para representar datos constantes, como coordenadas, fechas, y otros valores inmutables en bases de datos.
#
# Diccionarios: Útiles para mapas de datos como configuraciones, catálogos de productos o registros donde las claves son identificadores únicos.
#
# Conjuntos: Aplicables en la eliminación de duplicados en listas, la verificación de membresías o comparaciones entre conjuntos de datos.

# %%
nombres = ['GIOVANNY','KEVIN','ESTEBAN','JUAN', 'JOSÉ']
edades = [18,21,20,21,17]

# %%
for nombre in nombres:
  print(nombre.lower())
# Out:
# giovanny
# kevin
# esteban
# juan
# josé

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nombres_mini = [nombre.lower() for nombre in nombres]

# %%
nombres_mini
# Out:
# ['giovanny', 'kevin', 'esteban', 'juan', 'josé']

# %%
pesos = [60, 55, 65]
alturas = [1.57, 1.60,1.70]

# %%
imc  = [round(peso/(altura**2),2) for peso, altura in zip(pesos,alturas)]

# %%
imc
# Out:
# [24.34, 21.48, 22.49]

# %%
print(set(zip(pesos,alturas)))
# Out:
# {(55, 1.6), (60, 1.57), (65, 1.7)}
